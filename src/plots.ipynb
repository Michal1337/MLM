# %%
import pandas as pd

# %%
df = pd.read_csv('results.csv')

# %%
df
# Out:
#                           stream  n_dim  n_points     detector  seq_len  \
# 0       generate_ar1_time_series      1      2000        ADWIN       16
# 1       generate_ar1_time_series      1      2000        ADWIN       16
# 2       generate_ar1_time_series      1      2000        ADWIN       16
# 3       generate_ar1_time_series      1      2000        ADWIN       32
# 4       generate_ar1_time_series      1      2000        ADWIN       32
# ..                           ...    ...       ...          ...      ...
# 481  generate_hybrid_time_series      5     10000  PageHinkley       32
# 482  generate_hybrid_time_series      5     10000  PageHinkley       32
# 483  generate_hybrid_time_series      5     10000  PageHinkley       64
# 484  generate_hybrid_time_series      5     10000  PageHinkley       64
# 485  generate_hybrid_time_series      5     10000  PageHinkley       64
#
#     hidden_sizes  train_loss  test_loss
# 0           [16]    0.209753   0.371352
# ...

# %%
import matplotlib.pyplot as plt

# Create the bar plot
ax = df.groupby("detector")[["train_loss", "test_loss"]].mean().plot.bar(
    figsize=(10, 6),          # Larger figure size
    rot=0,                    # Horizontal x-axis labels
    colormap='viridis',      # Optional: better color palette
    edgecolor='black',       # Better bar definition
)

# Add title and axis labels
ax.set_title("Average Train/Test Loss by Detector", fontsize=14)
ax.set_xlabel("Detector", fontsize=12)
ax.set_ylabel("Loss", fontsize=12)

# Optional: Add grid
ax.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
ax = df.groupby("n_points")[["train_loss", "test_loss"]].mean().plot.bar(
    figsize=(10, 6),          # Larger figure size
    rot=0,                    # Horizontal x-axis labels
    colormap='viridis',      # Optional: better color palette
    edgecolor='black',       # Better bar definition
)

# Add title and axis labels
ax.set_title("Average Train/Test Loss by N Points", fontsize=14)
ax.set_xlabel("N Points", fontsize=12)
ax.set_ylabel("Loss", fontsize=12)

# Optional: Add grid
ax.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
